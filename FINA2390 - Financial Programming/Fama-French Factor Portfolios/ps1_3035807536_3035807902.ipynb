# %% [markdown]
# # Problem Set 1
# ### Wong Tsz Wai 3035807536
# ### Kan Chi Fu   3035807902

# %% [markdown]
# This is the first homework assignment, which accounts for $15\%$ of your final grade. There are six questions, and their weights are:
# * Q1: $10\%$,
# * Q2: $15\%$,
# * Q3: $15\%$,
# * Q4: $10\%$,
# * Q5: $30\%$,
# * Q6: $30\%$.
#
# You may notice that the above weights sum up to $110\%$. In other words, even if you make mistakes in some subquestions, you can still get $100\%$ (Even if you get all the questions right, the maximum score you can obtain is no more than $100\%$).
#
# You may work with other students. The maximum number of students per group is two. However, you can work on your own. Be sure to indicate with whom you have worked in your submission.
#
# ### Deadline: October 4, 2023 (5 PM HK Time).
#
# There is a penalty for late submissions: $5\%$ will be subtracted from the total mark for every additional day after the deadline.

# %% [markdown]
# ---

# %% [markdown]
# ## Q1. Cafe Menu ($10\%$)

# %% [markdown]
# Write a program that
# * first displays a simple cafe menu (see details below),
# * asks the user to enter the number of a choice, and
# * either **prints the appropriate action** OR **prints an error message that their choice was not valid.**
#
#
# #### Example of printing the appropriate action:
#
# Cafe Menu:
# 1. Expresso
# 2. Long Black
# 3. Cold Brew
# 4. Mocha
# 5. Latte
# 6. Cappuccino
#
# Which number would you like to order?5
#
# Thanks for ordering Latte.
#
# ----------
# #### Example of printing an error message that their choice was not valid:
#
# Cafe Menu:
# 1. Expresso
# 2. Long Black
# 3. Cold Brew
# 4. Mocha
# 5. Latte
# 6. Cappuccino
#
# Which number would you like to order? 10
#
# Sorry, that is not a valid choice.

# %%
def display_menu():
    '''Print a menu of coffee
    Return: a menu stored as a list'''

    menu = ["Expresso", "Long Black", "Cold Brew", "Mocha", "Latte", "Cappuccino"]

    #--print menu------#
    print("Cafe Menu:\n")
    for i, item in enumerate(menu, 1):
        print(f"{i}. {item}")
    #------------------#
    return menu

def get_order(menu):
    '''Get order from user input
    menu (list): a predetermined menu of coffee
    Return: an integer storing the order'''

    choice = int(input("\nWhich number would you like to order? "))
    return choice

def show_order(menu,choice):
    '''Print the ordered product
    menu (list): a predetermined menu of coffee
    choice (int): an integer storing the order'''

    #--print ordered product if it is in the menu, else print error message--#
    try:
        order = menu[choice-1]
        print(f"\nThanks for ordering {order}.")
    except:
        print("Sorry, that is not a valid choice.")
    #------------------------------------------------------------------------#

def main():
    menu = display_menu()
    choice = get_order(menu)
    show_order(menu,choice)

main()
# Out:
# Cafe Menu:
#
# 1. Expresso
# 2. Long Black
# 3. Cold Brew
# 4. Mocha
# 5. Latte
# 6. Cappuccino
# Sorry, that is not a valid choice.

# %% [markdown]
# ## Q2. Approximating $\pi$ ($15\%$)

# %% [markdown]
# In this question, we aim to approximate $\pi$, which is around $3.141592653589793...$.
#
# Let's look at the below figure: The square target has a length of two cm and the circular target has a radius of one cm. Using high-school mathematics, we know that the ratio of the area of the circle to the area of the square is
# $$
# \frac{\text{area of circle}}{\text{area of square}} = \frac{\pi \times 1^2}{2^2} = \frac{\pi}{4}.
# $$
#
# How do we use the above relationship to approximate $\pi$? We rely on the idea of Monte-Carlo simulations. Let's say we simulate data in the 2-D square, with some points $(x,y)$. $x$ and $y$ follows uniform distributions taking values in $[-1,+1]$. For every single point $(x,y)$, its probability of entering the circle is exactly $\frac{\pi}{4}$. When we repeat this experiment for many times (e.g., 100,000 times), we can count the frequency of $(x,y)$ entering the circle, and this percentage should be close to $\frac{\pi}{4}$.

# %% [markdown]
# ![Screenshot%202023-08-02%20at%203.35.25%20PM.png](attachment:Screenshot%202023-08-02%20at%203.35.25%20PM.png)

# %% [markdown]
# Motivated by the above argument, you are required to write a function that approximates $\pi$. Some hints:
# * You need to use the built-in module ```random``` to simulate random numbers. For example, if you want to simulate a point from a uniform distribution $[-1,+1]$, you can do the following:
# ```python
# import random   # first import the built-in module
# x = random.uniform(-1,1)
# y = random.uniform(-1,1)
# ```
# * After you simulate ```x``` and ```y```, you need to determine whether the point $(x,y)$ enters the circle by checking ```x**2+y**2 <= 1```.
#
# Here is the specification of the funtion that you are asked to write:
# ```python
# def approximate_pi(num_steps):
#    """
#    num_steps int, the number of steps in Monte-Carlo simultions;
#    Return an approximation of pi using Monte-Carlo simultions.
#    """
# ```
#
# After you write down your codes, please try the following:
# ```python
# import random
# print("Approximated value of pi using 1000 Monte-Carlo simulations:", approximate_pi(1000))
# print("Approximated value of pi using 10000 Monte-Carlo simulations:", approximate_pi(10000))
# print("Approximated value of pi using 100000 Monte-Carlo simulations:", approximate_pi(100000))
# import math
# print("True value of pi given by Python", math.pi)
# ```

# %%
def approximate_pi(num_steps):
    """
    num_steps int, the number of steps in Monte-Carlo simultions;
    Return an approximation of pi using Monte-Carlo simultions.
    """ 
    points_inside_circle = 0

    #--count random generated points in the circle--#
    for _ in range(num_steps):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)

        if x**2 + y**2 <= 1:
            points_inside_circle += 1
    #-----------------------------------------------#

    pi_approximation = 4 * points_inside_circle / num_steps
    return pi_approximation

import random
print("Approximated value of pi using 1000 Monte-Carlo simulations:", approximate_pi(1000))
print("Approximated value of pi using 10000 Monte-Carlo simulations:", approximate_pi(10000))
print("Approximated value of pi using 100000 Monte-Carlo simulations:", approximate_pi(100000))
import math
print("True value of pi given by Python:", math.pi)
# Out:
# Approximated value of pi using 1000 Monte-Carlo simulations: 3.28
# Approximated value of pi using 10000 Monte-Carlo simulations: 3.1568
# Approximated value of pi using 100000 Monte-Carlo simulations: 3.1416
# True value of pi given by Python: 3.141592653589793

# %% [markdown]
# ---

# %% [markdown]
# ## Q3. Permutations of a String Using Recursion ($15\%$)

# %% [markdown]
# This question comes from the course "*6.0001 Introduction to Computer Science and Programming in Python*" at MIT.
#
# A permutation is simply a name for a reordering. So the permutations of the string ‘abc’ are ‘abc’, ‘acb’, ‘bac’, ‘bca’, ‘cab’, and ‘cba’. Note that a sequence is a permutation of itself (the trivial permutation). You’ll need to write a **recursive** function ```get_permutations``` that takes a string and returns a list of all its permutations.
#
# Note: **Recursion MUST be used, global variables may NOT be used**. Additionally, it is okay to use loops to code the solution. The order of the returned permutations does not matter. Please also avoid returning duplicates in your final list.

# %% [markdown]
# #### Suggested Approach
#
# In order to solve any recursive problem, we must have at least one base case and a recursive case (or cases). In this approach, our base case is if ```sequence``` is a single character (there’s only one way to order a single character).
#
# If ```sequence``` is longer than one character, we need to identify a simpler version of the problem that, if solved, will help us easily find all permutations for ```sequence```. The pseudocode is:
# * Base case:
#  * if ```sequence``` is a single character, there’s only one way to order it
#    * return a singleton list containing ```sequence```
# * Recursive case:
#  * suppose we have a method that can give us a list of all permutations of **all but the first character** in ```sequence``` (Hint: think recursion),
#  * then the permutations of all characters in ```sequence``` would be the combination of the first character and a list of all permutations of the remaining strings. For example,
#    * if our word was ```'bust'```, we hold out the character ```'b'``` and get the list ```['ust', 'sut', 'stu', 'uts', 'tus', 'tsu']```, then we return ```['bust', 'bsut', 'bstu', 'buts', 'btus', 'btsu']```.
#    * if we hold out the character ```'u'``` and get the list ```['bst', 'sbt', 'stb', 'bts', 'tbs', 'tsb']```, then we return ```['ubst', 'usbt', 'ustb', 'ubts', 'utbs', 'utsb']```.
#    * ......

# %% [markdown]
# ```python
# def get_permutations(sequence):
#     '''
#     Enumerate all permutations of a given string
#
#     sequence (string): an arbitrary string to permute. Assume that it is a non-empty string.
#
#     You MUST use recursion for this part. Non-recursive solutions will not be accepted.
#
#     Returns: a list of all permutations of sequence
#
#     Example:
#     >>> get_permutations('abc')
#     ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
#
#     Note: depending on your implementation, you may return the permutations in
#     a different order than what is listed here.
#     '''
#
# ```

# %%
def get_permutations(sequence):
    '''
    Enumerate all permutations of a given string

    sequence (string): an arbitrary string to permute. Assume that it is a non-empty string.  

    Returns: a list of all permutations of sequence
    '''
    
    assert sequence!='' and isinstance(sequence,str), 'sequence is an non-empty string'

    # Base case: sequence is a single character, return the character
    if len(sequence) <= 1:
        return (sequence)
    #----------------------------------------------#

    # Recursive case:
    
    permutations = []

    for i in range(len(sequence)):
        # create sub-permutation for every character in the sequence
        first_character = sequence[i]
        remaining_characters = sequence[:i] + sequence[i+1:]
        other_permutations = get_permutations(remaining_characters)

        # append sub-permutations
        for other_permutations in other_permutations:
            permutations.append(first_character + other_permutations)

    return permutations
    #----------------------------------------------#
    

string = 'bust'
permutations=get_permutations(string)
print(permutations)
# Out:
# ['bust', 'buts', 'bsut', 'bstu', 'btus', 'btsu', 'ubst', 'ubts', 'usbt', 'ustb', 'utbs', 'utsb', 'sbut', 'sbtu', 'subt', 'sutb', 'stbu', 'stub', 'tbus', 'tbsu', 'tubs', 'tusb', 'tsbu', 'tsub']

# %% [markdown]
# ---

# %% [markdown]
# ## Q4. Simple Exercise of ```dict``` ($10\%$)

# %% [markdown]
# Suppose that there are eight types of coffee (```cafe_list```), and we know their prices (```price_list```).
# ```python
# cafe_list = ['Expresso', 'Long Black', 'Cold Brew', 'Mocha', 'Latte', 'Cappuccino',
#              'Flat White', 'Dirty Original']
# price_list = [30, 40, 38, 45, 42, 42, 42, 45]
# ```
#
# Write a program that combines these lists into a dictionary, *where we require coffee prices to be the keys and coffee names to be the values (lists of coffee names)*. Then, write a function that, given the price, returns the names of all coffee types with the same price (or ```None``` if no coffee type has this price). For example,
# ```python
# print(coffee(42)) = ['Latte', 'Cappuccino', 'Flat White']
# ```

# %%
coffee_list = ['Expresso', 'Long Black', 'Cold Brew', 'Mocha', 'Latte', 'Cappuccino', 'Flat White', 'Dirty Original']
price_list = [30, 40, 38, 45, 42, 42, 42, 45]
def lists_to_dict(coffee_list, price_list):
    '''Create coffee dict from lists
    coffe_list (list): list of coffee
    price_list (list): list of price corresponding to that coffee, i.e. price of coffee_list[i] is price_list[i]
    Return: a dict of coffees hashed by price'''
    
    coffee_dict = {}
    for coffee, price in zip(coffee_list, price_list):
        if price in coffee_dict:
            coffee_dict[price].append(coffee)
        else:
            coffee_dict[price] = [coffee]
    return coffee_dict

coffee_dict = lists_to_dict(coffee_list, price_list)
print(coffee_dict)

def coffee(price):
    '''Get a list of coffees selling at the price
    price (int,float): price of coffee
    Return: coffee list selling at that price, None if no coffee selling at that price'''
    if price in coffee_dict:
        return coffee_dict[price]
    else:
        return None

print(coffee(42))
# Out:
# {30: ['Expresso'], 40: ['Long Black'], 38: ['Cold Brew'], 45: ['Mocha', 'Dirty Original'], 42: ['Latte', 'Cappuccino', 'Flat White']}
# ['Latte', 'Cappuccino', 'Flat White']

# %% [markdown]
# ---

# %% [markdown]
# ## Q5. Newton-Raphson Algorithm ($30\%$)

# %% [markdown]
# In week 1, we introduced the bisection search, which was used to find the square root of a positive real number. However, we have an even faster algorithm, called ***Newton-Raphson*** algorithm. It can be used to find the real roots of many differentiable functions. In this question, we explore how to use Newton-Raphson algorithm to find out the square root of a positive real number.
#
# Suppose that $f(x)$ is a scalar function that has real roots $x_0$, i.e., $f(x_0) = 0$. Examples of $f(x)$ include $f(x) = x^2 - 9$, $f(x) = 3 x^2 + 2x +3$, etc. The Taylor expansion implies that
# $$
# f(x_0) - f(x) \approx f'(x) (x_0 - x) \implies x_0 \approx x - \frac{f(x)}{f'(x)},
# $$
# where $f'(x)$ is the first-order derivative of $f(x)$, and we use the fact that $f(x_0) = 0$ in the above derivation.
#
# This implies that given the current guess in the $t$-th iteration, the $(t+1)$-th guess equals
# $$
# x_{t+1} = x_t - \frac{f(x_t)}{f'(x_t)}.
# $$
#
# Since we now consider the square root, $f(x) = x^2 - k$, which means $x$ is the square root of $k$ if $f(x) = x^2 - k = 0$. The Newton-Raphson Algorithm is
# $$
# x_{t+1} = x_t - \frac{x^2_t - k}{2 \cdot x_t}.
# $$

# %% [markdown]
# ### Q5.1

# %% [markdown]
# Using the background information that we described, you are asked to write a function that finds the approximate square root of a positive real number, with the following function specification:
# ```python
# def square_root_newton(k, epsilon, max_steps=1000):
#     """
#     Assumes that k and epsilon int or float, max_steps int.
#     epsilon > 0 & k >= 0.
#     Returns float x such that k**2 is within epsilon of k.
#     If such a float does not exist (the number of loops is more than max_steps), it returns None.
#     """
# ```
#
# Hint: you may need to use the following codes to update your guess: ```guess = guess - (((guess**2) - k)/(2*guess))```
#
#
# Examples of executing ```square_root_newton``` function:
# ```python
# print(square_root_newton(-256, 0.001))
# print(square_root_newton(256, 0.001))
# ```
# will output
#
# None
#
# 16.000003310579185

# %%
def square_root_newton(k, epsilon, max_steps=1000):
    """
    Assumes that k and epsilon int or float, max_steps int.
    epsilon > 0 & k >= 0. 
    Returns float x such that k**2 is within epsilon of k.
    If such a float does not exist (the number of loops is more than max_steps), it returns None. 
    """

    ## handling assumptions
    if k < 0 or epsilon <= 0:
        return None

    # initializing variables
    guess = k /2  
    steps = 0

    # estimate the square root recursively until error is smaller than epsilon
    while abs(guess**2 - k) >= epsilon:
        guess = guess - (((guess**2) - k) / (2 * guess))
        steps += 1

        # terminate if no solution is found in max_steps allowed
        if steps > max_steps:
            return None

    return guess

print(square_root_newton(-256, 0.001))
print(square_root_newton(256, 0.001))
# Out:
# None
# 16.000003310579185

# %% [markdown]
# ### Q5.2

# %% [markdown]
# In lecture 3, we introduced a function ```test_my_square_root``` to test whether ```my_square_root``` has bugs. In this question, you are required to write a test function for ```square_root_newton```. You should consider all boundary cases.

# %%
def test_square_root_newton():
    # Test case 1: Square root of a positive number
    k = 16
    epsilon = 0.001
    expected_result = 4.000000636692939
    result = square_root_newton(k, epsilon)
    print(square_root_newton(k,epsilon))
    assert abs(result - expected_result) < epsilon, f"Test case 1 failed: Expected {expected_result}, got {result}"

    # Test case 2: Square root of zero
    k = 0
    epsilon = 0.001
    expected_result = 0.0
    result = square_root_newton(k, epsilon)
    print(square_root_newton(k,epsilon))
    assert abs(result - expected_result) < epsilon, f"Test case 2 failed: Expected {expected_result}, got {result}"

    # Test case 3: Square root of a large number
    k = 1000000
    epsilon = 0.001
    expected_result = 1000.0
    result = square_root_newton(k, epsilon)
    print(square_root_newton(k,epsilon))
    assert abs(result - expected_result) < epsilon, f"Test case 3 failed: Expected {expected_result}, got {result}"

    # Test case 4: Square root of a negative number
    k = -25
    epsilon = 0.001
    expected_result = None
    result = square_root_newton(k, epsilon)
    print(square_root_newton(k,epsilon))
    assert result == expected_result, f"Test case 4 failed: Expected {expected_result}, got {result}"

    # Test case 5: Square root with a large epsilon
    k = 9
    epsilon = 100
    expected_result = 3.0
    result = square_root_newton(k, epsilon)
    print(square_root_newton(k,epsilon))
    assert abs(result - expected_result) < epsilon, f"Test case 5 failed: Expected {expected_result}, got {result}"

    # Test case 6: Square root of a large prime number
    k = 53982894593057
    epsilon = 0.001
    expected_result = math.sqrt(k)
    result = square_root_newton(k, epsilon)
    print(square_root_newton(k,epsilon))
    assert abs(result - expected_result) < epsilon, f"Test case 3 failed: Expected {expected_result}, got {result}"


test_square_root_newton()
# Out:
# 4.0000001858445895
# 0.0
# 1000.0000000000117
# None
# 4.5
# 7347305.260641959

# %% [markdown]
# ### Q5.3

# %% [markdown]
# You are required to compare the efficiency (run time) of the function ```square_root_newton``` with the one using bisection search. Which one is more efficient?
#
# Hint: use the ```import``` package.
# ```python
# import timeit
# %timeit square_root_newton(256, 0.001)
# ```

# %%
def square_root_bisection(k, epsilon, max_steps=1000):

    numGuesses = 0
    low = 0.0
    high = max(1.0, k)
    ans = (high + low)/2.0

    while abs(ans**2 - k) >= epsilon:
        numGuesses += 1
        if ans**2 < k:
            low = ans 
        else:
            high = ans
        ans = (high + low)/2.0

# time the functions on different k
def time_square_root_newton(ks,epsilon):
    for k in ks:
        square_root_newton(k,epsilon)

def time_square_root_bisection(ks,epsilon):
    for k in ks:
        square_root_bisection(k,epsilon)


import timeit

# generate random set of ks, so %timeit gives an average time of the functions
ks = [random.uniform(0,100000) for _ in range(1000)]
epsilon = 0.001

print('square_root_newton() average running time on 1000 random ks:')
# %timeit time_square_root_newton(ks,epsilon)

print('-----------------------')

print('square_root_bisection() average running time on 1000 random ks:')
# %timeit time_square_root_bisection(ks,epsilon)
# Out:
# square_root_newton() average running time on 1000 random ks:
# 4.69 ms ± 270 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# -----------------------
# square_root_bisection() average running time on 1000 random ks:
# 12.4 ms ± 587 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Q5.4

# %% [markdown]
# One common strategy of defensive programming is to use ***assertions***. For example, users of the function ```square_root_newton``` may mistakenly assign some bad values of ```k```, e.g., $k=-4$. Whenever the values or types of ```k```, ```epsilon```, and ```max_steps``` do not satisfy the specifications, an assertation (e.g., ```AssertionError: Bad input```) should be raised! In this question, you are required to rewrite the ```square_root_newton``` function to have the assertation statement.
#
# ```python
# def square_root_newton(k, epsilon, max_steps=1000):
#     """
#     Assumes that k and epsilon int or float, max_steps int. epsilon > 0 & k >= 0 & max_steps > 0.
#     If the values or types of k, epsilon, and max_steps do not satisfy the above requirements,
#     an assertation (e.g., AssertionError: Bad input) should raised!
#     Returns float x such that k**2 is within epsilon of k.
#     If such a float does not exist (the number of loops is more than max_steps), it returns None.
#     """
# ```

# %% [markdown]
# #### An example:

# %% [markdown]
# ![Screenshot%202023-09-08%20at%209.39.42%20AM.png](attachment:Screenshot%202023-09-08%20at%209.39.42%20AM.png)

# %%
def square_root_newton(k, epsilon, max_steps=1000):
    """
    Assumes that k and epsilon int or float, max_steps int. epsilon > 0 & k >= 0 & max_steps > 0.
    If the values or types of k, epsilon, and max_steps do not satisfy the above requirements,
    an assertation (e.g., AssertionError: Bad input) should raised!
    Returns float x such that k**2 is within epsilon of k.
    If such a float does not exist (the number of loops is more than max_steps), it returns None. 
    """
    assert (isinstance(k, (int, float)) and
            isinstance(epsilon, (int, float)) and
            isinstance(max_steps, int) and
            epsilon > 0 and
            k >= 0 and
            max_steps > 0), "Bad input"
        
    # initializing variables
    guess = k /2  
    steps = 0

    # estimate the square root recursively until error is smaller than epsilon
    while abs(guess**2 - k) >= epsilon:
        guess = guess - (((guess**2) - k) / (2 * guess))
        steps += 1

        # terminate if no solution is found in max_steps allowed
        if steps > max_steps:
            return None

    return guess

print(square_root_newton(4, -0.001))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/benkan45d6/Documents/Study/HKU/2023 Sem 1/FINA2390/0. Assignment/ps1 copy.ipynb Cell 39 line <cell line: 31>()
#      <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=26'>27</a>             return None
#      <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=28'>29</a>     return guess
# ---> <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=30'>31</a> print(square_root_newton(4, -0.001))
#
# /Users/benkan45d6/Documents/Study/HKU/2023 Sem 1/FINA2390/0. Assignment/ps1 copy.ipynb Cell 39 line square_root_newton(k, epsilon, max_steps)
#       <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> def square_root_newton(k, epsilon, max_steps=1000):
#       <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=1'>2</a>     """
#       <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=2'>3</a>     Assumes that k and epsilon int or float, max_steps int. epsilon > 0 & k >= 0 & max_steps > 0.
#       <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=3'>4</a>     If the values or types of k, epsilon, and max_steps do not satisfy the above requirements,
#    (...)
#       <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=6'>7</a>     If such a float does not exist (the number of loops is more than max_steps), it returns None.
#       <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=7'>8</a>     """
# ----> <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=8'>9</a>     assert (isinstance(k, (int, float)) and
#      <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=9'>10</a>             isinstance(epsilon, (int, float)) and
#      <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=10'>11</a>             isinstance(max_steps, int) and
#      <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=11'>12</a>             epsilon > 0 and
#      <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=12'>13</a>             k >= 0 and
#      <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=13'>14</a>             max_steps > 0), "Bad input"
#      <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=15'>16</a>     # initializing variables
#      <a href='vscode-notebook-cell:/Users/benkan45d6/Documents/Study/HKU/2023%20Sem%201/FINA2390/0.%20Assignment/ps1%20copy.ipynb#X53sZmlsZQ%3D%3D?line=16'>17</a>     guess = k /2
#
# AssertionError: Bad input

# %% [markdown]
# ---

# %% [markdown]
# ## Q6. A New Class of Discounted Cash Flow (DCF) Analysis  ($30\%$)

# %% [markdown]
# **How do you value an investment project?** This is one of the most popular investment banking interview questions. A short answer to this question is to use discounted cash flow (DCF) analysis. The DCF says that the value of a productive asset equals the present value of its cash flows. In this question, we explore how to build a new class for the DCF analysis and further build several subclasses, which are used to model some special cases of DCF analysis.

# %% [markdown]
# Suppose a project can generate a scream of cash flows: You get $C_1$ at time $1$, get $C_2$ at time $2$, ..., get $C_T$ at time $T$, as shown below. The present value ($PV_0$) at time $0$ is the sum of discounted future cash flows:
# $$
# PV_0 = \sum_{t=1}^T \frac{C_t}{(1+r)^t}.
# $$

# %% [markdown]
# ![Screenshot%202023-08-02%20at%209.27.03%20PM.png](attachment:Screenshot%202023-08-02%20at%209.27.03%20PM.png)

# %% [markdown]
# ### Several special cases

# %% [markdown]
# * **Perpetuity**: Pays Constant Cash Flows C Forever, with the present value $PV_0 = \frac{C}{r}$. <br>
# <br>
# * **Annuity**: Pays Constant Cash Flow C for T periods， with the present value $PV_0 = \frac{C}{r} \times \big[ 1 - \frac{1}{(1+r)^T} \big] $. <br>
# <br>
# * **Growing Perpetuity**: Is a growing stream of cash flows that lasts forever. You get $C_1$ at time $1$, get $C_1 \times (1+g)$ at time $2$, ..., get $C_1 \times (1+g)^{T-1}$ at time $T$, ... forever, where $g$ is the growth rate of future cash flows. Thus, the present value is $PV_0 = \frac{C_1}{r-g}$. <br>
# <br>
# * **Growing Annuity**: Is a growing stream of cash flows with a fixed maturity $T$. The present value is therefore $PV_0 = \frac{C}{r-g} \times \big[ 1 - \frac{1}{(\frac{1+g}{1+r})^T} \big] $ ($C = C_1$).

# %% [markdown]
# ### Net Present Value (NPV)
#
# How do you determine whether to take or reject a new investment project? We often use the **Net Present Value (NPV)** rule. Suppose that $P_0$ denotes the cost of entering this project (or equivalently, the price of buying this projecting). The NPV of the project is defined as  <br>
# <br>
# $$
# NPV = PV_0 - P_0,
# $$
# <br>
# and we should take (or reject) the project if and only if its NPV is positive (or negative).
#
# Furthermore, if you compare two investment projects A and B, you should choose the one with positive and higher NPV (e.g., choose project A over B if $NPV_A > NPV_B$).

# %% [markdown]
# ### Q6.1
#
# You are asked to create a new class named ```DCF```. The skeleton of the codes is:
# ```python
# class DCF(object):
#     """Abstract class for building different kinds of DCF analyses"""
#
#     def __init__(self, discount_rate, num_periods, cash_flows_streams, proj_name, proj_price=None):
#         """Create a new DCF analysis"""
#         pass  # you need to remove this and fill in your codes
#
#     def PV(self):
#         """Return the present value of all future cash flows generated by this project"""
#         pass  # you need to remove this and fill in your codes
#
#     def NPV(self):
#         """Return the net present value of all future cash flows generated by this project"""
#         pass  # you need to remove this and fill in your codes
#
#     def __lt__(self, other):
#         """Returns True if self's NPV is less than other's NPV, and False otherwise"""
#         pass  # you need to remove this and fill in your codes
#
#     def __str__(self):
#         """Print the object"""
#         pass  # you need to remove this and fill in your codes
# ```

# %% [markdown]
# There are several investment projects:
#
# * **Project 1**. You are considering an investment that will pay you $\$1,000$ in one year, $\$2,000$ in two years and $\$3,000$ in three years. If you want to earn $10\%$ on your money, how much would you be willing to pay?
#  * To answer this question, you will use the following codes:
# ```python
# project1 = DCF(discount_rate=0.1, num_periods=3, cash_flows_streams=[1000,2000,3000], proj_name="project 1")
# print(project1)
# print("Present value of project 1:", project1.PV())
# print("Net present value of project 1:", project1.NPV())
# ```
#  * with the output:
#
# project name: project 1
#
# discount rate: 0.1
#
# number of periods: 3
#
# Present value of project 1: 4815.927873779112
#
# You forgot to put the project price
#
# Net present value of project 1: None

# %%
class DCF(object):
    """Abstract class for building different kinds of DCF analyses"""
    
    def __init__(self, discount_rate, num_periods, cash_flows_streams, proj_name, proj_price=None):
        """Create a new DCF analysis"""
        self.discount_rate = discount_rate
        self.num_periods = num_periods
        self.cash_flows_streams = cash_flows_streams
        self.proj_name = proj_name
        self.proj_price = proj_price
    
    def PV(self):
        """Return the present value of all future cash flows generated by this project"""
        total_pv = 0
        r = self.discount_rate
        for i,cf in enumerate(self.cash_flows_streams):
            t = i+1
            total_pv += cf/(1+r)**t
        return total_pv
    
    def NPV(self):
        """Return the net present value of all future cash flows generated by this project"""
        try:
            npv = self.PV() - self.proj_price
        except:
            print('You forgot to put the project price')
            npv = None
        return npv

    def __lt__(self, other):
        """Returns True if self's NPV is less than other's NPV, and False otherwise"""
        lt = self.NPV() < other.NPV()
        return lt
            
    def __str__(self):
        """Print the object"""
        lines = [f'project name: {self.proj_name}\n',
                 f'discount rate: {self.discount_rate}\n',
                 f'number of periods: {self.num_periods}']
        string = ''
        for line in lines:
            string += line
        return string

# %% [markdown]
# You are considering an investment that will pay you $\$1,000$ in one year, $\$2,000$ in two years and $\$3,000$ in three years. If you want to earn $10\%$ on your money, how much would you be willing to pay (what is the present value of this project)?

# %%
project1 = DCF(discount_rate=0.1, num_periods=3, cash_flows_streams=[1000,2000,3000], proj_name="project 1")
print(project1)
print("Present value of project 1:", project1.PV())
print("Net present value of project 1:", project1.NPV())
# Out:
# project name: project 1
# discount rate: 0.1
# number of periods: 3
# Present value of project 1: 4815.927873779112
# You forgot to put the project price
# Net present value of project 1: None

# %% [markdown]
# * **Project 2**. Your broker calls you and tells you that he has this great investment opportunity. If you invest $\$100$ today, you will receive $\$40$ in one year and $\$75$ in two years. If you require a $15\%$ return on investments of this risk, should you take the investment (is the NPV of this project positive)?

# %%
project2 = DCF(discount_rate=0.15, num_periods=2, cash_flows_streams=[40,75], proj_name="project 2",proj_price=100)
print(project2)
print("Present value of project 2:", project2.PV(),'\n')
print("Net present value of project 2:", project2.NPV())
# Out:
# project name: project 2
# discount rate: 0.15
# number of periods: 2
# Present value of project 2: 91.49338374291116
#
# Net present value of project 2: -8.506616257088837

# %% [markdown]
# Suppose that there are two projects:
# * Project 3. Today you need to pay $\$150$ to kick off this project. Over the next three years, you will receive $\$40$, $\$75$, and $\$100$.
# * Project 4. Today you need to pay $\$150$ to kick off this project. Over the next four years, you will receive $\$20$, $\$55$, $\$100$, and $\$100$.
#
# If the discount rate is $15\%$, do you prefer project 3 or 4 (whether project 3 or 4 has a larger NPV)?

# %%
project3 = DCF(discount_rate=0.15, num_periods=3, cash_flows_streams=[40,75,100], proj_name="project 3",proj_price=150)
print(project3)
print("Present value of project 3:", project3.PV(),'\n')
print("Net present value of project 3:", project3.NPV(),'\n')

project4 = DCF(discount_rate=0.15, num_periods=4, cash_flows_streams=[20,55,100,100], proj_name="project 4",proj_price=150)
print(project4)
print("Present value of project 4:", project4.PV(),'\n')
print("Net present value of project 4:", project4.NPV())
# Out:
# project name: project 3
# discount rate: 0.15
# number of periods: 3
# Present value of project 3: 157.24500698610998
#
# Net present value of project 3: 7.245006986109985
#
# project name: project 4
# discount rate: 0.15
# number of periods: 4
# Present value of project 4: 181.9061538516515
#
# Net present value of project 4: 31.90615385165151

# %% [markdown]
# ### Q6.2
#
# You are asked to build a **subclass** of ```DCF```, called ```Perpetuity```.  The skeleton of the codes is:
# ```python
# class Perpetuity(DCF):
#
#     def __init__(self, discount_rate, cash_flows_constant, grow_rate, proj_name, proj_price=None):
#         """Create a new DCF analysis"""
#         pass  # you need to remove this and fill in your codes
#
#     def PV(self):
#         """Return the present value of all future cash flows generated by this project"""
#         pass  # you need to remove this and fill in your codes
#
#     def __str__(self):
#         """Print the object"""
#         pass  # you need to remove this and fill in your codes
# ```
#
# Question: In the 1800’s, the British government decided to consolidate all its debt and do a single issue of perpetuities (called “consols”). $2.5\%$ consols are still traded today, promising $£25$ every year. Suppose the interest rate in the UK is approximately $10\%$. What is the price of a consol promising $£25$ every year?
#
# **If you use the following codes:**
# ```python
# consol = Perpetuity(0.1, 25, 0, "UK consol")
# print(consol)
# print("Present value of consol:", consol.PV())
# ```
#
# **Then you will get the following output:**
#
# Perpetuity
#
# project name: UK consol
#
# discount rate: 0.1
#
# Growth rate of cash flows: 0
#
# number of periods: Infinity
#
# Present value of consol: 250.0

# %%
class Perpetuity(DCF):
    
    def __init__(self, discount_rate, cash_flows_constant, grow_rate, proj_name, proj_price=None):
        """Create a new DCF analysis"""
        DCF.__init__(self,discount_rate=discount_rate,num_periods='Infinity',cash_flows_streams=[],proj_name=proj_name,proj_price=proj_price)
        self.cash_flows_constant = cash_flows_constant
        self.grow_rate = grow_rate
    
    def PV(self):
        """Return the present value of all future cash flows generated by this project"""
        c = self.cash_flows_constant
        g = self.grow_rate
        r = self.discount_rate
        total_pv = c/(r-g)
        return total_pv
        
    def __str__(self):
        """Print the object"""
        lines = ['Perpetuity\n',
                 f'project name: {self.proj_name}\n',
                 f'discount rate: {self.discount_rate}\n',
                 f'Growth rate of cash flows: {self.grow_rate}\n',
                 f'number of periods: {self.num_periods}']
        string = ''
        for line in lines:
            string += line
        return string
    
consol = Perpetuity(0.1, 25, 0, "UK consol")
print(consol)
print("Present value of consol:", consol.PV())
# Out:
# Perpetuity
# project name: UK consol
# discount rate: 0.1
# Growth rate of cash flows: 0
# number of periods: Infinity
# Present value of consol: 250.0

# %% [markdown]
# ### Q6.3
#
# You are asked to build a subclass of ```DCF```, called ```Annuity```.  The skeleton of the codes is:
# ```python
# class Annuity(DCF):
#
#     def __init__(self, discount_rate, num_periods, cash_flows_constant, grow_rate,
#                  proj_name, proj_price=None):
#         """Create a new DCF analysis"""
#         pass  # you need to remove this and fill in your codes
#
#     def PV(self):
#         """Return the present value of all future cash flows generated by this project"""
#         pass  # you need to remove this and fill in your codes
#
#     def __str__(self):
#         """Print the object"""
#         pass  # you need to remove this and fill in your codes
#
# ```
#
# Question: A retirement plan offers to pay for $40$ years: The payment in year 1 equals $\$20,000$ and increases by $3\%$ each year. What is the present value at retirement if the discount rate is $10\%$?
#
# **If you use the following codes:**
# ```python
# retirement_plan = Annuity(0.1, 40, 20000, 0.03, "retirement plan")
# print(retirement_plan)
# print("Present value of the retirement plan:", retirement_plan.PV())
# ```
#
# **Then you will get the following output:**
#
# Annuity
#
# project name: retirement plan
#
# discount rate: 0.1
#
# Growth rate of cash flows: 0.03
#
# number of periods: 40
#
# Present value of the retirement plan: 265121.5741017385

# %%
class Annuity(DCF):
    
    def __init__(self, discount_rate, num_periods, cash_flows_constant, grow_rate, proj_name, proj_price=None):
        """Create a new DCF analysis"""
        DCF.__init__(self,discount_rate=discount_rate,num_periods=num_periods,cash_flows_streams=[],proj_name=proj_name,proj_price=proj_price)
        self.cash_flows_constant = cash_flows_constant
        self.grow_rate = grow_rate 
    
    def PV(self):
        """Return the present value of all future cash flows generated by this project"""
        c = self.cash_flows_constant
        g = self.grow_rate
        r = self.discount_rate
        T = self.num_periods
        
        numerator = 1-((1+g)/(1+r))**T
        denominator = r-g
        
        total_pv = c*(numerator/denominator)
        return total_pv
    
    def __str__(self):
        """Print the object"""
        lines = ['Annuity\n',
                 f'project name: {self.proj_name}\n',
                 f'discount rate: {self.discount_rate}\n',
                 f'Growth rate of cash flows: {self.grow_rate}\n',
                 f'number of periods: {self.num_periods}']
        string = ''
        for line in lines:
            string += line
        return string
    
retirement_plan = Annuity(0.1, 40, 20000, 0.03, "retirement plan")
print(retirement_plan)
print("Present value of the retirement plan:", retirement_plan.PV())
# Out:
# Annuity
# project name: retirement plan
# discount rate: 0.1
# Growth rate of cash flows: 0.03
# number of periods: 40
# Present value of the retirement plan: 265121.5741017385

# %% [markdown]
# ---

# %% [markdown]
# # END
